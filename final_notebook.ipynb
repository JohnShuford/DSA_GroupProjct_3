# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: folium in ./.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.13/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2025.11.12)

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.graph.t_edgeWeight()
path_A_to_J_traffic = nav.find_route('A', 'J', traffic=True)
print("Path found with traffic:", path_A_to_J)
# Out:
# Path found with traffic: [0, 1, 3, 5, 9]

# %%
nav.print_route_details('A', 'J')
nav.print_route_details('A', 'J', traffic = True)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================
#
#
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → C → E → I → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  C: Szczesliwicki Park (17.0 mins)
#  E: Warsaw West Train Station (11.0 mins)
#  I: National Museum in Warsaw (14.6 mins)
#  J: PGE Narodowy Stadium (10.5 mins)
#
# Total Travel Time: 53.2 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_254ce66708cea338a793123ef9b1cb7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_254ce66708cea338a793123ef9b1cb7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_254ce66708cea338a793123ef9b1cb7b = L.map(
#                 &quot;map_254ce66708cea338a793123ef9b1cb7b&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a490e72dcce4f837356c97c255ba3bc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a490e72dcce4f837356c97c255ba3bc2.addTo(map_254ce66708cea338a793123ef9b1cb7b);
#
#
#             var marker_b6af6a0b622a524d6e713ca13383bb7c = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_254ce66708cea338a793123ef9b1cb7b);
#
#
#             var icon_0aa3874605b852353cfae9caa3ba3dff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f18363d76b518718dfeeeb0d07329b94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa195520b773f67a1ba39ce0873814fe = $(`&lt;div id=&quot;html_fa195520b773f67a1ba39ce0873814fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_f18363d76b518718dfeeeb0d07329b94.setContent(html_fa195520b773f67a1ba39ce0873814fe);
#
#
#
#         marker_b6af6a0b622a524d6e713ca13383bb7c.bindPopup(popup_f18363d76b518718dfeeeb0d07329b94)
#         ;
#
#
#
#
#             marker_b6af6a0b622a524d6e713ca13383bb7c.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b6af6a0b622a524d6e713ca13383bb7c.setIcon(icon_0aa3874605b852353cfae9caa3ba3dff);
#
#
#             var marker_b00ee1cb2b7c8b22d3a629633183defc = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_254ce66708cea338a793123ef9b1cb7b);
#
#
#             var icon_21bd8761b274ddfce440f097a6c17b84 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_899a216342ca88682b52db799579c83f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de2b3494f17191165efcb794f242512e = $(`&lt;div id=&quot;html_de2b3494f17191165efcb794f242512e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_899a216342ca88682b52db799579c83f.setContent(html_de2b3494f17191165efcb794f242512e);
#
#
#
#         marker_b00ee1cb2b7c8b22d3a629633183defc.bindPopup(popup_899a216342ca88682b52db799579c83f)
#         ;
#
#
#
#
#             marker_b00ee1cb2b7c8b22d3a629633183defc.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b00ee1cb2b7c8b22d3a629633183defc.setIcon(icon_21bd8761b274ddfce440f097a6c17b84);
#
#
#             var marker_57c371164fa222677463e0b069a91eb0 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_254ce66708cea338a793123ef9b1cb7b);
#
#
#             var icon_ff8d97924f19be666e53f574b561d51f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4b36201166a38cff3c80801e8b1f59ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffb680e1598588a376bb226419e5a60f = $(`&lt;div id=&quot;html_ffb680e1598588a376bb226419e5a60

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e02af37ac67010f5104f05ffcafc3c29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e02af37ac67010f5104f05ffcafc3c29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e02af37ac67010f5104f05ffcafc3c29 = L.map(
#                 &quot;map_e02af37ac67010f5104f05ffcafc3c29&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfa084db4f5863818824b9fee0f30ebf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfa084db4f5863818824b9fee0f30ebf.addTo(map_e02af37ac67010f5104f05ffcafc3c29);
#
#
#             var marker_2e64214725e2401551f2bd7f653df7f4 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_e02af37ac67010f5104f05ffcafc3c29);
#
#
#             var icon_1898d9f951d50ee2a8810f8de469977c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0316d224e6e4c44f2d3ff82156b580ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d13e87635406efd0e5f54cdb54a0c71a = $(`&lt;div id=&quot;html_d13e87635406efd0e5f54cdb54a0c71a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_0316d224e6e4c44f2d3ff82156b580ae.setContent(html_d13e87635406efd0e5f54cdb54a0c71a);
#
#
#
#         marker_2e64214725e2401551f2bd7f653df7f4.bindPopup(popup_0316d224e6e4c44f2d3ff82156b580ae)
#         ;
#
#
#
#
#             marker_2e64214725e2401551f2bd7f653df7f4.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2e64214725e2401551f2bd7f653df7f4.setIcon(icon_1898d9f951d50ee2a8810f8de469977c);
#
#
#             var marker_e76eaf16173fa114e1c66ba338832617 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_e02af37ac67010f5104f05ffcafc3c29);
#
#
#             var icon_7a5ca76c5be53c0927288471b24131fc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3d46625bdbfeab820bd0c418eb36543f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fd1d17017e1b7deaf596646824d67fe = $(`&lt;div id=&quot;html_4fd1d17017e1b7deaf596646824d67fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_3d46625bdbfeab820bd0c418eb36543f.setContent(html_4fd1d17017e1b7deaf596646824d67fe);
#
#
#
#         marker_e76eaf16173fa114e1c66ba338832617.bindPopup(popup_3d46625bdbfeab820bd0c418eb36543f)
#         ;
#
#
#
#
#             marker_e76eaf16173fa114e1c66ba338832617.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e76eaf16173fa114e1c66ba338832617.setIcon(icon_7a5ca76c5be53c0927288471b24131fc);
#
#
#             var marker_b286d3fb9de95b7e8d73715f8691589c = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_e02af37ac67010f5104f05ffcafc3c29);
#
#
#             var icon_e666ebdd5c8ae49f4be2c6846b0a4642 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b1cf354583565c8a4bcf09e53a1a644d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_488ab5b42564635b843fa06584c04618 = $(`&lt;div id=&quot;html_488ab5b42564635b843fa06584c046

# %%
map_A_to_J_traffic = nav.create_path_map(path_A_to_J_traffic)
map_A_to_J_traffic
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54d6b9fef8a98b4201d11ea40f5f97be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54d6b9fef8a98b4201d11ea40f5f97be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54d6b9fef8a98b4201d11ea40f5f97be = L.map(
#                 &quot;map_54d6b9fef8a98b4201d11ea40f5f97be&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdc475c7bdc90a521c1795be4e128302 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdc475c7bdc90a521c1795be4e128302.addTo(map_54d6b9fef8a98b4201d11ea40f5f97be);
#
#
#             var marker_545d630731410ea44b5454b4459026d4 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_54d6b9fef8a98b4201d11ea40f5f97be);
#
#
#             var icon_e37efe7cb0f565bc87eeee86963a9023 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1d2ac385cc60af649fb37926db15fc78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87527d86a0fb99786e93f54a6cd76d33 = $(`&lt;div id=&quot;html_87527d86a0fb99786e93f54a6cd76d33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_1d2ac385cc60af649fb37926db15fc78.setContent(html_87527d86a0fb99786e93f54a6cd76d33);
#
#
#
#         marker_545d630731410ea44b5454b4459026d4.bindPopup(popup_1d2ac385cc60af649fb37926db15fc78)
#         ;
#
#
#
#
#             marker_545d630731410ea44b5454b4459026d4.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_545d630731410ea44b5454b4459026d4.setIcon(icon_e37efe7cb0f565bc87eeee86963a9023);
#
#
#             var marker_c0122e7ff7226f4efe0dd28f659ab859 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_54d6b9fef8a98b4201d11ea40f5f97be);
#
#
#             var icon_c68c76ca1d4189a92cc9947a76276fba = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4db3d8515b265bafd0a518770107f9b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa70506ec3f4a7a9b4a2a1c1e5a72881 = $(`&lt;div id=&quot;html_aa70506ec3f4a7a9b4a2a1c1e5a72881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_4db3d8515b265bafd0a518770107f9b6.setContent(html_aa70506ec3f4a7a9b4a2a1c1e5a72881);
#
#
#
#         marker_c0122e7ff7226f4efe0dd28f659ab859.bindPopup(popup_4db3d8515b265bafd0a518770107f9b6)
#         ;
#
#
#
#
#             marker_c0122e7ff7226f4efe0dd28f659ab859.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c0122e7ff7226f4efe0dd28f659ab859.setIcon(icon_c68c76ca1d4189a92cc9947a76276fba);
#
#
#             var marker_6896460ec9dfae2c29fd0e24e81c166f = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_54d6b9fef8a98b4201d11ea40f5f97be);
#
#
#             var icon_9d85e82f00b365ce54a7faa13bd83dec = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d6b00efec65687d1a5fe5267cf3a94d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ab09b2f604f5f5eb1332bd93f42cf5a = $(`&lt;div id=&quot;html_4ab09b2f604f5f5eb1332bd93f42cf
