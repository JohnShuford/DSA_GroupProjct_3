# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: folium in ./.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.13/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2025.11.12)

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.graph.t_edgeWeight()
path_A_to_J_traffic = nav.find_route('A', 'J', traffic=True)
print("Path found with traffic:", path_A_to_J_traffic)
# Out:
# Path found with traffic: [0, 2, 3, 5, 9]

# %%
nav.print_route_details('A', 'J')
nav.print_route_details('A', 'J', traffic = True)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================
#
#
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → C → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  C: Szczesliwicki Park (11.0 mins)
#  D: SGH Warsaw School of Economics (12.0 mins)
#  F: Legia Warsaw Stadium (8.7 mins)
#  J: PGE Narodowy Stadium (6.7 mins)
#
# Total Travel Time: 38.4 minutes
# ============================================================

# %%
# Base Case with Uncertainty
nav.graph.apply_uncertainty()
path_A_to_J_uncertainty = nav.find_route("A", "J", traffic=False)
nav.print_route_details("A", "J", traffic=False)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================

# %%
# Traffic Case with Uncertainty & Traffic Multiplier
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
path = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (26.8 mins)
#  D: SGH Warsaw School of Economics (19.6 mins)
#  F: Legia Warsaw Stadium (23.0 mins)
#  J: PGE Narodowy Stadium (10.5 mins)
#
# Total Travel Time: 79.9 minutes
# ============================================================

# %%
# Traffic Case with Extreme Events
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
nav.graph.apply_extreme_events(num_edges=3)
# Out:
#  Extreme Event Report
# Disruption on edge 4-8: 13.1 → 130.9 mins
# Disruption on edge 0-2: 9.7 → 97.1 mins
# No disruption on edge 2-4 (normal conditions)
# {(0, 1): 9.018,
#  (1, 0): 9.018,
#  (0, 2): 97.1,
#  (2, 0): 97.1,
#  (1, 2): 13.58,
#  (2, 1): 13.58,
#  (1, 3): 10.175,
#  (3, 1): 10.175,
#  (2, 3): 12.395999999999999,
#  (3, 2): 12.395999999999999,
#  (2, 4): 9.95,
#  (4, 2): 9.95,
#  (3, 5): 8.272,
#  (5, 3): 8.272,
#  (3, 7): 8.232,
#  (7, 3): 8.232,
#  (4, 7): 12.768,
#  (7, 4): 12.768,
#  (4, 8): 130.92,
#  (8, 4): 130.92,
#  (5, 6): 5.550000000000001,
#  (6, 5): 5.550000000000001,
#  (5, 9): 3.668,
#  (9, 5): 3.668,
#  (6, 8): 6.168,
#  (8, 6): 6.168,
#  (6, 9): 6.492000000000001,
#  (9, 6): 6.492000000000001,
#  (7, 8): 2.907,
#  (8, 7): 2.907,
#  (8, 9): 5.34,
#  (9, 8): 5.34}

# %%
path_A_to_J_extreme = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (22.3 mins)
#  D: SGH Warsaw School of Economics (15.3 mins)
#  F: Legia Warsaw Stadium (8.6 mins)
#  J: PGE Narodowy Stadium (9.3 mins)
#
# Total Travel Time: 55.5 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_399c8f9aa7a1bfb347be08e3e789ea26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_399c8f9aa7a1bfb347be08e3e789ea26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_399c8f9aa7a1bfb347be08e3e789ea26 = L.map(
#                 &quot;map_399c8f9aa7a1bfb347be08e3e789ea26&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90407ce67efb4bec28247fbb8c2cb845 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90407ce67efb4bec28247fbb8c2cb845.addTo(map_399c8f9aa7a1bfb347be08e3e789ea26);
#
#
#             var marker_fdbe08b8f0b3d40c9489bd156d7646c8 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_399c8f9aa7a1bfb347be08e3e789ea26);
#
#
#             var icon_d253987f09f76a411059c2aa589e2a40 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1e15dc1ddf761731128fe9772187bf8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8b7da4fedd41056da8e21fefbd9934d = $(`&lt;div id=&quot;html_b8b7da4fedd41056da8e21fefbd9934d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_1e15dc1ddf761731128fe9772187bf8f.setContent(html_b8b7da4fedd41056da8e21fefbd9934d);
#
#
#
#         marker_fdbe08b8f0b3d40c9489bd156d7646c8.bindPopup(popup_1e15dc1ddf761731128fe9772187bf8f)
#         ;
#
#
#
#
#             marker_fdbe08b8f0b3d40c9489bd156d7646c8.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_fdbe08b8f0b3d40c9489bd156d7646c8.setIcon(icon_d253987f09f76a411059c2aa589e2a40);
#
#
#             var marker_bdda314c462d73be2198bc45c1837e2c = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_399c8f9aa7a1bfb347be08e3e789ea26);
#
#
#             var icon_5ef9ed8ffd12a0b108f05ed5480f785d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2215c3b422ebcdd9dca2b780cb8ecf8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4704a0c994ca8742b18e280ffe3f0e9 = $(`&lt;div id=&quot;html_c4704a0c994ca8742b18e280ffe3f0e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_2215c3b422ebcdd9dca2b780cb8ecf8d.setContent(html_c4704a0c994ca8742b18e280ffe3f0e9);
#
#
#
#         marker_bdda314c462d73be2198bc45c1837e2c.bindPopup(popup_2215c3b422ebcdd9dca2b780cb8ecf8d)
#         ;
#
#
#
#
#             marker_bdda314c462d73be2198bc45c1837e2c.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_bdda314c462d73be2198bc45c1837e2c.setIcon(icon_5ef9ed8ffd12a0b108f05ed5480f785d);
#
#
#             var marker_e48edc55f0e91aec9ef36cf431fabb7a = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_399c8f9aa7a1bfb347be08e3e789ea26);
#
#
#             var icon_79018bc79c6e316a7d3c34e91b6b747c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b86283c9d71f0309f6e52e3a5d855ebb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4ba82ae43df2c85666ac35b99bba4bc = $(`&lt;div id=&quot;html_d4ba82ae43df2c85666ac35b99bba4b

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2d9990a0fe55537d8bb3d31050b7bc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2d9990a0fe55537d8bb3d31050b7bc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2d9990a0fe55537d8bb3d31050b7bc8 = L.map(
#                 &quot;map_b2d9990a0fe55537d8bb3d31050b7bc8&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40cb9dcf0319ddbd8e0bee9214860cd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40cb9dcf0319ddbd8e0bee9214860cd8.addTo(map_b2d9990a0fe55537d8bb3d31050b7bc8);
#
#
#             var marker_688c1d029327a94884a54f656fb65cfc = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_b2d9990a0fe55537d8bb3d31050b7bc8);
#
#
#             var icon_44e7bfdded108d6d3f9acbffb4bbdf80 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d95eb74b53b5b83ef3686a9d975bb23e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_802811b3308f485d77d6061932b6b631 = $(`&lt;div id=&quot;html_802811b3308f485d77d6061932b6b631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_d95eb74b53b5b83ef3686a9d975bb23e.setContent(html_802811b3308f485d77d6061932b6b631);
#
#
#
#         marker_688c1d029327a94884a54f656fb65cfc.bindPopup(popup_d95eb74b53b5b83ef3686a9d975bb23e)
#         ;
#
#
#
#
#             marker_688c1d029327a94884a54f656fb65cfc.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_688c1d029327a94884a54f656fb65cfc.setIcon(icon_44e7bfdded108d6d3f9acbffb4bbdf80);
#
#
#             var marker_dab9566f55444b4d29d8715b7e31a116 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_b2d9990a0fe55537d8bb3d31050b7bc8);
#
#
#             var icon_1c8e636a63ffe5581afd2c0f3271f91f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_750564ddc4d6fd16344e3b7773f9ba3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0053d907ce1a838c0fba746ba76cc66 = $(`&lt;div id=&quot;html_e0053d907ce1a838c0fba746ba76cc66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_750564ddc4d6fd16344e3b7773f9ba3f.setContent(html_e0053d907ce1a838c0fba746ba76cc66);
#
#
#
#         marker_dab9566f55444b4d29d8715b7e31a116.bindPopup(popup_750564ddc4d6fd16344e3b7773f9ba3f)
#         ;
#
#
#
#
#             marker_dab9566f55444b4d29d8715b7e31a116.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_dab9566f55444b4d29d8715b7e31a116.setIcon(icon_1c8e636a63ffe5581afd2c0f3271f91f);
#
#
#             var marker_0b12505a639fe0a290e038c2055e4a41 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_b2d9990a0fe55537d8bb3d31050b7bc8);
#
#
#             var icon_e1026d2728d8f8afdace30745365e37b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_50b7cb776a6f2c5db5102813bb72f4b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf6bcb26a6eb4bd7c74a5e2b129f0c71 = $(`&lt;div id=&quot;html_cf6bcb26a6eb4bd7c74a5e2b129f0c

# %%
map_A_to_J_traffic = nav.create_path_map(path_A_to_J_traffic)
map_A_to_J_traffic
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ce78eb80cf442d5a0ca2727e3aa4ac9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ce78eb80cf442d5a0ca2727e3aa4ac9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ce78eb80cf442d5a0ca2727e3aa4ac9 = L.map(
#                 &quot;map_1ce78eb80cf442d5a0ca2727e3aa4ac9&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84a713000c0404834d92ef7460c1b8ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84a713000c0404834d92ef7460c1b8ee.addTo(map_1ce78eb80cf442d5a0ca2727e3aa4ac9);
#
#
#             var marker_956d96cc1dde40a9e0d5fc28ca7ee49c = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_1ce78eb80cf442d5a0ca2727e3aa4ac9);
#
#
#             var icon_07daba769633001e465d8ff88103f55d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ddae9989a514fcac33a104a2780f4e65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ac33992a63a7afbd634dbba3f85e989 = $(`&lt;div id=&quot;html_6ac33992a63a7afbd634dbba3f85e989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_ddae9989a514fcac33a104a2780f4e65.setContent(html_6ac33992a63a7afbd634dbba3f85e989);
#
#
#
#         marker_956d96cc1dde40a9e0d5fc28ca7ee49c.bindPopup(popup_ddae9989a514fcac33a104a2780f4e65)
#         ;
#
#
#
#
#             marker_956d96cc1dde40a9e0d5fc28ca7ee49c.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_956d96cc1dde40a9e0d5fc28ca7ee49c.setIcon(icon_07daba769633001e465d8ff88103f55d);
#
#
#             var marker_4b58216da80855850fbe0cd2a0632265 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_1ce78eb80cf442d5a0ca2727e3aa4ac9);
#
#
#             var icon_36945730ab21b0eb2dddc081ebeddd93 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8c0bb6b38bab51c00d4626a70273489e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0750d4c06d8fd4b12fc1cbc37cbc2510 = $(`&lt;div id=&quot;html_0750d4c06d8fd4b12fc1cbc37cbc2510&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_8c0bb6b38bab51c00d4626a70273489e.setContent(html_0750d4c06d8fd4b12fc1cbc37cbc2510);
#
#
#
#         marker_4b58216da80855850fbe0cd2a0632265.bindPopup(popup_8c0bb6b38bab51c00d4626a70273489e)
#         ;
#
#
#
#
#             marker_4b58216da80855850fbe0cd2a0632265.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4b58216da80855850fbe0cd2a0632265.setIcon(icon_36945730ab21b0eb2dddc081ebeddd93);
#
#
#             var marker_c6bb4baaddd3e0ec8531dae57d557021 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_1ce78eb80cf442d5a0ca2727e3aa4ac9);
#
#
#             var icon_6aefcd133a61317e6cee4db6d3ca0617 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_355abc441be305a30a945b06a5f1c8b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4802adf4a940ca2b98a2bfc3c2a79d91 = $(`&lt;div id=&quot;html_4802adf4a940ca2b98a2bfc3c2a79d

# %%
path_A_to_J_extreme = nav.create_path_map(path_A_to_J_extreme)
path_A_to_J_extreme
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_723407611120a7a242bd36fa171afc7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_723407611120a7a242bd36fa171afc7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_723407611120a7a242bd36fa171afc7f = L.map(
#                 &quot;map_723407611120a7a242bd36fa171afc7f&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9320c2571a44fddabdd201779bbf25f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9320c2571a44fddabdd201779bbf25f2.addTo(map_723407611120a7a242bd36fa171afc7f);
#
#
#             var marker_f72d8d75320ac048fbfab90d48bc7b75 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_723407611120a7a242bd36fa171afc7f);
#
#
#             var icon_d5a083588a85816615c03e644536ef76 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_977ec32d64b5c985c77e03c1524d6408 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_199b037b823544ab4aeca0b516d30817 = $(`&lt;div id=&quot;html_199b037b823544ab4aeca0b516d30817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_977ec32d64b5c985c77e03c1524d6408.setContent(html_199b037b823544ab4aeca0b516d30817);
#
#
#
#         marker_f72d8d75320ac048fbfab90d48bc7b75.bindPopup(popup_977ec32d64b5c985c77e03c1524d6408)
#         ;
#
#
#
#
#             marker_f72d8d75320ac048fbfab90d48bc7b75.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f72d8d75320ac048fbfab90d48bc7b75.setIcon(icon_d5a083588a85816615c03e644536ef76);
#
#
#             var marker_c63a51ce3ba27e0abb025bd5f8534937 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_723407611120a7a242bd36fa171afc7f);
#
#
#             var icon_28667a7eae2233c3f1729e94292da12f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a539e5f674bf09c453cfcd1e8d9dd30d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a93eb73f230695ea5845cbecf5fd4235 = $(`&lt;div id=&quot;html_a93eb73f230695ea5845cbecf5fd4235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_a539e5f674bf09c453cfcd1e8d9dd30d.setContent(html_a93eb73f230695ea5845cbecf5fd4235);
#
#
#
#         marker_c63a51ce3ba27e0abb025bd5f8534937.bindPopup(popup_a539e5f674bf09c453cfcd1e8d9dd30d)
#         ;
#
#
#
#
#             marker_c63a51ce3ba27e0abb025bd5f8534937.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c63a51ce3ba27e0abb025bd5f8534937.setIcon(icon_28667a7eae2233c3f1729e94292da12f);
#
#
#             var marker_4e8ab51f9c36407403a4931f5fa0f8f1 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_723407611120a7a242bd36fa171afc7f);
#
#
#             var icon_c2dcf83a228027cbfcdceab7f7b44f7f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_74b4b5e974482334e442b602d8566dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5d67c339306b3477b64f8dbd29cca5c = $(`&lt;div id=&quot;html_e5d67c339306b3477b64f8dbd29cca
