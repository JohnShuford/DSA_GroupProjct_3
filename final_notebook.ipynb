# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: folium in ./.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.13/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2025.11.12)

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.graph.t_edgeWeight()
path_A_to_J_traffic = nav.find_route('A', 'J', traffic=True)
print("Path found with traffic:", path_A_to_J)
# Out:
# Path found with traffic: [0, 1, 3, 5, 9]

# %%
nav.print_route_details('A', 'J')
nav.print_route_details('A', 'J', traffic = True)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================
#
#
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (16.7 mins)
#  D: SGH Warsaw School of Economics (17.2 mins)
#  F: Legia Warsaw Stadium (21.0 mins)
#  J: PGE Narodowy Stadium (5.0 mins)
#
# Total Travel Time: 59.9 minutes
# ============================================================

# %%
# Base Case with Uncertainty
nav.graph.apply_uncertainty()
path = nav.find_route("A", "J", traffic=False)
nav.print_route_details("A", "J", traffic=False)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================

# %%
# Traffic Case with Uncertainty & Traffic Multiplier
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
path = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (13.9 mins)
#  D: SGH Warsaw School of Economics (14.4 mins)
#  F: Legia Warsaw Stadium (12.3 mins)
#  J: PGE Narodowy Stadium (6.2 mins)
#
# Total Travel Time: 46.8 minutes
# ============================================================

# %%
# Traffic Case with Extreme Events
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
nav.graph.apply_extreme_events(num_edges=3)
# Out:
#  Extreme Event Report
# No disruption on edge 3-7 (normal conditions)
# No disruption on edge 6-8 (normal conditions)
# Disruption on edge 4-7: 12.4 → 123.6 mins
# {(0, 1): 9.765,
#  (1, 0): 9.765,
#  (0, 2): 9.65,
#  (2, 0): 9.65,
#  (1, 2): 15.120000000000001,
#  (2, 1): 15.120000000000001,
#  (1, 3): 10.658999999999999,
#  (3, 1): 10.658999999999999,
#  (2, 3): 10.848,
#  (3, 2): 10.848,
#  (2, 4): 9.98,
#  (4, 2): 9.98,
#  (3, 5): 8.104,
#  (5, 3): 8.104,
#  (3, 7): 8.8,
#  (7, 3): 8.8,
#  (4, 7): 123.6,
#  (7, 4): 123.6,
#  (4, 8): 12.072,
#  (8, 4): 12.072,
#  (5, 6): 6.12,
#  (6, 5): 6.12,
#  (5, 9): 3.988,
#  (9, 5): 3.988,
#  (6, 8): 5.958,
#  (8, 6): 5.958,
#  (6, 9): 5.718,
#  (9, 6): 5.718,
#  (7, 8): 2.889,
#  (8, 7): 2.889,
#  (8, 9): 5.455,
#  (9, 8): 5.455}

# %%
path = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (13.5 mins)
#  D: SGH Warsaw School of Economics (15.7 mins)
#  F: Legia Warsaw Stadium (22.6 mins)
#  J: PGE Narodowy Stadium (5.3 mins)
#
# Total Travel Time: 57.1 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_855b44ae68cd88ab4c0df96583ba1401 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_855b44ae68cd88ab4c0df96583ba1401&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_855b44ae68cd88ab4c0df96583ba1401 = L.map(
#                 &quot;map_855b44ae68cd88ab4c0df96583ba1401&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fe25269ff06036bd1d6f76feebca557 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fe25269ff06036bd1d6f76feebca557.addTo(map_855b44ae68cd88ab4c0df96583ba1401);
#
#
#             var marker_72657c8e8be7cb25f84b9edbfaaab833 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_855b44ae68cd88ab4c0df96583ba1401);
#
#
#             var icon_ab8a0ba0159a82be3acd2ba15231e4eb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c9dd35d5a0917b89d0ebe4fc8ed7a930 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_462f348545fa0eb01b3d198d566a58d2 = $(`&lt;div id=&quot;html_462f348545fa0eb01b3d198d566a58d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_c9dd35d5a0917b89d0ebe4fc8ed7a930.setContent(html_462f348545fa0eb01b3d198d566a58d2);
#
#
#
#         marker_72657c8e8be7cb25f84b9edbfaaab833.bindPopup(popup_c9dd35d5a0917b89d0ebe4fc8ed7a930)
#         ;
#
#
#
#
#             marker_72657c8e8be7cb25f84b9edbfaaab833.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_72657c8e8be7cb25f84b9edbfaaab833.setIcon(icon_ab8a0ba0159a82be3acd2ba15231e4eb);
#
#
#             var marker_4330c56ada9410831ee6200e0829e442 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_855b44ae68cd88ab4c0df96583ba1401);
#
#
#             var icon_b97709a81c8f22bf604d5420f648b18a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_175d001c63dc28ed7858f89effdfd253 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f883e380a92d73d366659aa9aee455d1 = $(`&lt;div id=&quot;html_f883e380a92d73d366659aa9aee455d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_175d001c63dc28ed7858f89effdfd253.setContent(html_f883e380a92d73d366659aa9aee455d1);
#
#
#
#         marker_4330c56ada9410831ee6200e0829e442.bindPopup(popup_175d001c63dc28ed7858f89effdfd253)
#         ;
#
#
#
#
#             marker_4330c56ada9410831ee6200e0829e442.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4330c56ada9410831ee6200e0829e442.setIcon(icon_b97709a81c8f22bf604d5420f648b18a);
#
#
#             var marker_3eafe137662b8e9efcea092ccea6b17e = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_855b44ae68cd88ab4c0df96583ba1401);
#
#
#             var icon_02f105177dcd7d949f6d95767a665f39 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_56af49f99134003c30cfa64e2f384c8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_507cc10815df4173b773af648f7f3c45 = $(`&lt;div id=&quot;html_507cc10815df4173b773af648f7f3c4

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6233daef2ef33d0d9c1a0228416b12af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6233daef2ef33d0d9c1a0228416b12af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6233daef2ef33d0d9c1a0228416b12af = L.map(
#                 &quot;map_6233daef2ef33d0d9c1a0228416b12af&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e36a3fc5fbe402ed03f49fd17dc4e6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e36a3fc5fbe402ed03f49fd17dc4e6f.addTo(map_6233daef2ef33d0d9c1a0228416b12af);
#
#
#             var marker_deabef2324156f41172ac30e1955e557 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_6233daef2ef33d0d9c1a0228416b12af);
#
#
#             var icon_008a8fcfaee894424f759454fa152161 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c6ac407eb799885be5cd0fd89fcbd3c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce1e98a2f431f38986d6bf90b7c33556 = $(`&lt;div id=&quot;html_ce1e98a2f431f38986d6bf90b7c33556&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_c6ac407eb799885be5cd0fd89fcbd3c1.setContent(html_ce1e98a2f431f38986d6bf90b7c33556);
#
#
#
#         marker_deabef2324156f41172ac30e1955e557.bindPopup(popup_c6ac407eb799885be5cd0fd89fcbd3c1)
#         ;
#
#
#
#
#             marker_deabef2324156f41172ac30e1955e557.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_deabef2324156f41172ac30e1955e557.setIcon(icon_008a8fcfaee894424f759454fa152161);
#
#
#             var marker_07ce00cb414044c34510e70691535135 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_6233daef2ef33d0d9c1a0228416b12af);
#
#
#             var icon_daa2833bb1cde6ea1e2ff80456d7e823 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2e30b739ff353bc7c62bb546ae03a06a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8d4755406f84bd6ac9f144072b69e7f = $(`&lt;div id=&quot;html_c8d4755406f84bd6ac9f144072b69e7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_2e30b739ff353bc7c62bb546ae03a06a.setContent(html_c8d4755406f84bd6ac9f144072b69e7f);
#
#
#
#         marker_07ce00cb414044c34510e70691535135.bindPopup(popup_2e30b739ff353bc7c62bb546ae03a06a)
#         ;
#
#
#
#
#             marker_07ce00cb414044c34510e70691535135.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_07ce00cb414044c34510e70691535135.setIcon(icon_daa2833bb1cde6ea1e2ff80456d7e823);
#
#
#             var marker_b64e983973c10ebf13359ba2a8393e75 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_6233daef2ef33d0d9c1a0228416b12af);
#
#
#             var icon_c468110cb7df8c2333ce51d3a47e6879 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_84c0c3b6a0015bf257ecdb19b29fc276 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7575946d583f7cdfd3ec471dee801f0 = $(`&lt;div id=&quot;html_f7575946d583f7cdfd3ec471dee801

# %%
map_A_to_J_traffic = nav.create_path_map(path_A_to_J_traffic)
map_A_to_J_traffic
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd87059be938d798416adc436c345102 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd87059be938d798416adc436c345102&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd87059be938d798416adc436c345102 = L.map(
#                 &quot;map_fd87059be938d798416adc436c345102&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ee9be4f3bfec6c1f38356a391214ef1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ee9be4f3bfec6c1f38356a391214ef1.addTo(map_fd87059be938d798416adc436c345102);
#
#
#             var marker_7ca687c1e843593e707e981ace7c7721 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_fd87059be938d798416adc436c345102);
#
#
#             var icon_202fcc69df85f1d8b3067bb723218f79 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4634b260edd0667a108c90e05cc212ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87d16d21d945db8c7912909c3be38e19 = $(`&lt;div id=&quot;html_87d16d21d945db8c7912909c3be38e19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_4634b260edd0667a108c90e05cc212ed.setContent(html_87d16d21d945db8c7912909c3be38e19);
#
#
#
#         marker_7ca687c1e843593e707e981ace7c7721.bindPopup(popup_4634b260edd0667a108c90e05cc212ed)
#         ;
#
#
#
#
#             marker_7ca687c1e843593e707e981ace7c7721.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7ca687c1e843593e707e981ace7c7721.setIcon(icon_202fcc69df85f1d8b3067bb723218f79);
#
#
#             var marker_a1253dea4b94107a54ab743db0b8a358 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_fd87059be938d798416adc436c345102);
#
#
#             var icon_4019f19913460df88b5a72e908a7bf39 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f81ca78efad059d596f05888dde00586 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48a4d811bc253d8cbe944aaded06c957 = $(`&lt;div id=&quot;html_48a4d811bc253d8cbe944aaded06c957&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_f81ca78efad059d596f05888dde00586.setContent(html_48a4d811bc253d8cbe944aaded06c957);
#
#
#
#         marker_a1253dea4b94107a54ab743db0b8a358.bindPopup(popup_f81ca78efad059d596f05888dde00586)
#         ;
#
#
#
#
#             marker_a1253dea4b94107a54ab743db0b8a358.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a1253dea4b94107a54ab743db0b8a358.setIcon(icon_4019f19913460df88b5a72e908a7bf39);
#
#
#             var marker_eca4e50783f0cd84c00cff40b698dbc5 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_fd87059be938d798416adc436c345102);
#
#
#             var icon_db87c32daccd11c788ef012a7f80d464 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c63027a25dfd348878bdea4d81a33c64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9c98b3fb44da4f3f8a5eadebb7c8dee = $(`&lt;div id=&quot;html_b9c98b3fb44da4f3f8a5eadebb7c8d
