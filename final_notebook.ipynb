# %%
#%pip install folium

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.print_route_details('A', 'J')
# Out:
# ============================================================
# Route from A to J
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#   A: Warsaw Chopin Airport
#   B: Sluzewiec Horse Racetrack
#   D: SGH Warsaw School of Economics
#   F: Legia Warsaw Stadium
#   J: PGE Narodowy Stadium
#
# Total Travel Time: 32 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f2f0dd761711d7c6727609a856a0c64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f2f0dd761711d7c6727609a856a0c64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f2f0dd761711d7c6727609a856a0c64 = L.map(
#                 &quot;map_7f2f0dd761711d7c6727609a856a0c64&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cff1e6d9e662e6d3f7e3d221c0e0ea46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cff1e6d9e662e6d3f7e3d221c0e0ea46.addTo(map_7f2f0dd761711d7c6727609a856a0c64);
#
#
#             var marker_ef9b76d5729984931cfbe457c1dbe4ec = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_7f2f0dd761711d7c6727609a856a0c64);
#
#
#             var icon_0f0fe01fdd9dd6e5645b90b24f455163 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a681232d766a8095e089c9aab5e91862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36b0c71199a83bfa368def90f2631d17 = $(`&lt;div id=&quot;html_36b0c71199a83bfa368def90f2631d17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_a681232d766a8095e089c9aab5e91862.setContent(html_36b0c71199a83bfa368def90f2631d17);
#
#
#
#         marker_ef9b76d5729984931cfbe457c1dbe4ec.bindPopup(popup_a681232d766a8095e089c9aab5e91862)
#         ;
#
#
#
#
#             marker_ef9b76d5729984931cfbe457c1dbe4ec.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ef9b76d5729984931cfbe457c1dbe4ec.setIcon(icon_0f0fe01fdd9dd6e5645b90b24f455163);
#
#
#             var marker_a310a99be8179fc4066e9d402ee2cfff = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_7f2f0dd761711d7c6727609a856a0c64);
#
#
#             var icon_47b0ca381609a6b237c155d8f623b470 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_39c81e2b33d94d5446e67a2742a1f098 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d802205403d0d87089cc317eb21bf31d = $(`&lt;div id=&quot;html_d802205403d0d87089cc317eb21bf31d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_39c81e2b33d94d5446e67a2742a1f098.setContent(html_d802205403d0d87089cc317eb21bf31d);
#
#
#
#         marker_a310a99be8179fc4066e9d402ee2cfff.bindPopup(popup_39c81e2b33d94d5446e67a2742a1f098)
#         ;
#
#
#
#
#             marker_a310a99be8179fc4066e9d402ee2cfff.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a310a99be8179fc4066e9d402ee2cfff.setIcon(icon_47b0ca381609a6b237c155d8f623b470);
#
#
#             var marker_b27c0771d6439222e8e6c40dd51535d2 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_7f2f0dd761711d7c6727609a856a0c64);
#
#
#             var icon_c94540da2efff35946584cd5f2ca6a76 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_37badb40815c4526de4a9b5f5f7ca3ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eb7b6b4ce86620d8cbf141e0dd0aee8 = $(`&lt;div id=&quot;html_3eb7b6b4ce86620d8cbf141e0dd0aee

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fadf6347efafed1dd9a3fdf77c10c376 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fadf6347efafed1dd9a3fdf77c10c376&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fadf6347efafed1dd9a3fdf77c10c376 = L.map(
#                 &quot;map_fadf6347efafed1dd9a3fdf77c10c376&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bce6b4fccc5832a8743b8c29ef8b4980 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bce6b4fccc5832a8743b8c29ef8b4980.addTo(map_fadf6347efafed1dd9a3fdf77c10c376);
#
#
#             var marker_1c2707fde2151efce629ea44a9a94827 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_fadf6347efafed1dd9a3fdf77c10c376);
#
#
#             var icon_3594a982ddfd04dae9fecb1859956d47 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a4093b3486cd8a4d31699c46a97399f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d3a09223a4057ad3773233bf783f4d4 = $(`&lt;div id=&quot;html_4d3a09223a4057ad3773233bf783f4d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_a4093b3486cd8a4d31699c46a97399f7.setContent(html_4d3a09223a4057ad3773233bf783f4d4);
#
#
#
#         marker_1c2707fde2151efce629ea44a9a94827.bindPopup(popup_a4093b3486cd8a4d31699c46a97399f7)
#         ;
#
#
#
#
#             marker_1c2707fde2151efce629ea44a9a94827.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1c2707fde2151efce629ea44a9a94827.setIcon(icon_3594a982ddfd04dae9fecb1859956d47);
#
#
#             var marker_022d31aa61199f021073b271f4fe7122 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_fadf6347efafed1dd9a3fdf77c10c376);
#
#
#             var icon_19a254c5d7f28d95b7fc9c97bc0965f4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a699836c69e5ffce4aa902e10ba4102a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5114ceed428a41126b7a85c13b481f10 = $(`&lt;div id=&quot;html_5114ceed428a41126b7a85c13b481f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_a699836c69e5ffce4aa902e10ba4102a.setContent(html_5114ceed428a41126b7a85c13b481f10);
#
#
#
#         marker_022d31aa61199f021073b271f4fe7122.bindPopup(popup_a699836c69e5ffce4aa902e10ba4102a)
#         ;
#
#
#
#
#             marker_022d31aa61199f021073b271f4fe7122.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_022d31aa61199f021073b271f4fe7122.setIcon(icon_19a254c5d7f28d95b7fc9c97bc0965f4);
#
#
#             var marker_5d531c790b2b07f428e1d0eb1927829d = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_fadf6347efafed1dd9a3fdf77c10c376);
#
#
#             var icon_ef863fb833f7091af7be1dcf59bf7d09 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d43d435a6377c15eac9513e581601748 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81acbf2557dd86f5ceab65df5a3df28d = $(`&lt;div id=&quot;html_81acbf2557dd86f5ceab65df5a3df2
