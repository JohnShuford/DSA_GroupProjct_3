# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: folium in ./.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.13/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2025.11.12)

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.graph.t_edgeWeight()
path_A_to_J_traffic = nav.find_route('A', 'J', traffic=True)
print("Path found with traffic:", path_A_to_J_traffic)
# Out:
# Path found with traffic: [0, 1, 3, 5, 9]

# %%
nav.print_route_details('A', 'J')
nav.print_route_details('A', 'J', traffic = True)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================
#
#
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (20.5 mins)
#  D: SGH Warsaw School of Economics (25.9 mins)
#  F: Legia Warsaw Stadium (15.9 mins)
#  J: PGE Narodowy Stadium (5.6 mins)
#
# Total Travel Time: 67.9 minutes
# ============================================================

# %%
# Base Case with Uncertainty
nav.graph.apply_uncertainty()
path_A_to_J_uncertainty = nav.find_route("A", "J", traffic=False)
nav.print_route_details("A", "J", traffic=False)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================

# %%
# Traffic Case with Uncertainty & Traffic Multiplier
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
path = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (14.5 mins)
#  D: SGH Warsaw School of Economics (32.2 mins)
#  F: Legia Warsaw Stadium (12.8 mins)
#  J: PGE Narodowy Stadium (4.6 mins)
#
# Total Travel Time: 64.2 minutes
# ============================================================

# %%
# Traffic Case with Extreme Events
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
nav.graph.apply_extreme_events(num_edges=3)
# Out:
#  Extreme Event Report
# No disruption on edge 0-1 (normal conditions)
# No disruption on edge 2-4 (normal conditions)
# No disruption on edge 6-8 (normal conditions)
# {(0, 1): 8.883,
#  (1, 0): 8.883,
#  (0, 2): 10.03,
#  (2, 0): 10.03,
#  (1, 2): 13.902,
#  (2, 1): 13.902,
#  (1, 3): 10.328999999999999,
#  (3, 1): 10.328999999999999,
#  (2, 3): 11.58,
#  (3, 2): 11.58,
#  (2, 4): 10.64,
#  (4, 2): 10.64,
#  (3, 5): 8.224,
#  (5, 3): 8.224,
#  (3, 7): 7.608,
#  (7, 3): 7.608,
#  (4, 7): 11.687999999999999,
#  (7, 4): 11.687999999999999,
#  (4, 8): 11.975999999999999,
#  (8, 4): 11.975999999999999,
#  (5, 6): 5.88,
#  (6, 5): 5.88,
#  (5, 9): 4.22,
#  (9, 5): 4.22,
#  (6, 8): 6.588000000000001,
#  (8, 6): 6.588000000000001,
#  (6, 9): 6.204000000000001,
#  (9, 6): 6.204000000000001,
#  (7, 8): 3.1109999999999998,
#  (8, 7): 3.1109999999999998,
#  (8, 9): 4.72,
#  (9, 8): 4.72}

# %%
path_A_to_J_extreme = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (25.4 mins)
#  D: SGH Warsaw School of Economics (31.7 mins)
#  F: Legia Warsaw Stadium (19.0 mins)
#  J: PGE Narodowy Stadium (9.8 mins)
#
# Total Travel Time: 85.9 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93dcd0285dc37a0e41c60c9d09596fa5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93dcd0285dc37a0e41c60c9d09596fa5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93dcd0285dc37a0e41c60c9d09596fa5 = L.map(
#                 &quot;map_93dcd0285dc37a0e41c60c9d09596fa5&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3aa2623db703bbce8c7ab84f55bb1a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3aa2623db703bbce8c7ab84f55bb1a8.addTo(map_93dcd0285dc37a0e41c60c9d09596fa5);
#
#
#             var marker_225e92f091f76c82062f7022bc091ac0 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_93dcd0285dc37a0e41c60c9d09596fa5);
#
#
#             var icon_cd0ac76126c704a9e2e89658b31152f6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad3ade6a365551ad9dbbcbff4f702e3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d14f44786b1873ff73df6d5b54025994 = $(`&lt;div id=&quot;html_d14f44786b1873ff73df6d5b54025994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_ad3ade6a365551ad9dbbcbff4f702e3a.setContent(html_d14f44786b1873ff73df6d5b54025994);
#
#
#
#         marker_225e92f091f76c82062f7022bc091ac0.bindPopup(popup_ad3ade6a365551ad9dbbcbff4f702e3a)
#         ;
#
#
#
#
#             marker_225e92f091f76c82062f7022bc091ac0.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_225e92f091f76c82062f7022bc091ac0.setIcon(icon_cd0ac76126c704a9e2e89658b31152f6);
#
#
#             var marker_980caf95a9f7d23ef1ac98425fdf0539 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_93dcd0285dc37a0e41c60c9d09596fa5);
#
#
#             var icon_ba8fa5f185fa0d7f79503d43b3c4973b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_62b376ab85913a3b546ae78fdf62fb74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f993e424a98a9a9e08f50cfea81ff37d = $(`&lt;div id=&quot;html_f993e424a98a9a9e08f50cfea81ff37d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_62b376ab85913a3b546ae78fdf62fb74.setContent(html_f993e424a98a9a9e08f50cfea81ff37d);
#
#
#
#         marker_980caf95a9f7d23ef1ac98425fdf0539.bindPopup(popup_62b376ab85913a3b546ae78fdf62fb74)
#         ;
#
#
#
#
#             marker_980caf95a9f7d23ef1ac98425fdf0539.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_980caf95a9f7d23ef1ac98425fdf0539.setIcon(icon_ba8fa5f185fa0d7f79503d43b3c4973b);
#
#
#             var marker_2366802bed23e1d1bee74deef8333ec3 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_93dcd0285dc37a0e41c60c9d09596fa5);
#
#
#             var icon_65ea4260113ca6d4e7fdcf8063d2f9b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_67e5c12de0124518cee0cca008b2d779 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb784eeb73fc61f057ce4b248207d66f = $(`&lt;div id=&quot;html_bb784eeb73fc61f057ce4b248207d66

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c414216aca2fb881f2c918104160667 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c414216aca2fb881f2c918104160667&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c414216aca2fb881f2c918104160667 = L.map(
#                 &quot;map_4c414216aca2fb881f2c918104160667&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3bacfe6bd044058667c5b2972d6f238 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3bacfe6bd044058667c5b2972d6f238.addTo(map_4c414216aca2fb881f2c918104160667);
#
#
#             var marker_7f892e481cd8b680d54ec9f24476bb19 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_4c414216aca2fb881f2c918104160667);
#
#
#             var icon_bf8e95db81c56a1509cdcdbd337eeeed = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_92193c3875ac613bb946f72c784c4ddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa018a74152e57bb8e38690ebe44d1be = $(`&lt;div id=&quot;html_fa018a74152e57bb8e38690ebe44d1be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_92193c3875ac613bb946f72c784c4ddd.setContent(html_fa018a74152e57bb8e38690ebe44d1be);
#
#
#
#         marker_7f892e481cd8b680d54ec9f24476bb19.bindPopup(popup_92193c3875ac613bb946f72c784c4ddd)
#         ;
#
#
#
#
#             marker_7f892e481cd8b680d54ec9f24476bb19.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7f892e481cd8b680d54ec9f24476bb19.setIcon(icon_bf8e95db81c56a1509cdcdbd337eeeed);
#
#
#             var marker_c2bcf3abcab6a0627e59253d84b29d4e = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_4c414216aca2fb881f2c918104160667);
#
#
#             var icon_4e7d95c14f8f84a12e8fd6630fa6f06a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4f56f9cd17b7fd9a0f47c5bb7c57a231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494471ed71ac84d088f7026bd7e34020 = $(`&lt;div id=&quot;html_494471ed71ac84d088f7026bd7e34020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_4f56f9cd17b7fd9a0f47c5bb7c57a231.setContent(html_494471ed71ac84d088f7026bd7e34020);
#
#
#
#         marker_c2bcf3abcab6a0627e59253d84b29d4e.bindPopup(popup_4f56f9cd17b7fd9a0f47c5bb7c57a231)
#         ;
#
#
#
#
#             marker_c2bcf3abcab6a0627e59253d84b29d4e.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c2bcf3abcab6a0627e59253d84b29d4e.setIcon(icon_4e7d95c14f8f84a12e8fd6630fa6f06a);
#
#
#             var marker_fd2e99c262dc438231e0e97a8b3caf39 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_4c414216aca2fb881f2c918104160667);
#
#
#             var icon_a4f0fdd25ff1b0a1eb37b0f7a9fbb019 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0080fc23692591ea1a24982124035e0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7607122ae78f9caeed7f8a2ffa19e28 = $(`&lt;div id=&quot;html_d7607122ae78f9caeed7f8a2ffa19e

# %%
map_A_to_J_traffic = nav.create_path_map(path_A_to_J_traffic)
map_A_to_J_traffic
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3693e2429ab95d0badb25c9ebc3ae3c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3693e2429ab95d0badb25c9ebc3ae3c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3693e2429ab95d0badb25c9ebc3ae3c7 = L.map(
#                 &quot;map_3693e2429ab95d0badb25c9ebc3ae3c7&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebe52a826b876d120a797ea81c9316d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebe52a826b876d120a797ea81c9316d7.addTo(map_3693e2429ab95d0badb25c9ebc3ae3c7);
#
#
#             var marker_22f19d83f60bde17b0c01403249affcb = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_3693e2429ab95d0badb25c9ebc3ae3c7);
#
#
#             var icon_8339854283cc4777ec001fcd02f2b7d7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e88a252ce48ae03a69e3c63f1c3c2425 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_624ca032b45763f7895cebe5e1bd86fa = $(`&lt;div id=&quot;html_624ca032b45763f7895cebe5e1bd86fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_e88a252ce48ae03a69e3c63f1c3c2425.setContent(html_624ca032b45763f7895cebe5e1bd86fa);
#
#
#
#         marker_22f19d83f60bde17b0c01403249affcb.bindPopup(popup_e88a252ce48ae03a69e3c63f1c3c2425)
#         ;
#
#
#
#
#             marker_22f19d83f60bde17b0c01403249affcb.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_22f19d83f60bde17b0c01403249affcb.setIcon(icon_8339854283cc4777ec001fcd02f2b7d7);
#
#
#             var marker_5c86419c3c2cd6ec877e4263d2d6b399 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_3693e2429ab95d0badb25c9ebc3ae3c7);
#
#
#             var icon_ed36dace9c8b6d8c6db9fd3ee165c948 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_81bdef242c33dbb6433417a956e2ef2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83a564a7750c816e852d1b3751981c11 = $(`&lt;div id=&quot;html_83a564a7750c816e852d1b3751981c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_81bdef242c33dbb6433417a956e2ef2e.setContent(html_83a564a7750c816e852d1b3751981c11);
#
#
#
#         marker_5c86419c3c2cd6ec877e4263d2d6b399.bindPopup(popup_81bdef242c33dbb6433417a956e2ef2e)
#         ;
#
#
#
#
#             marker_5c86419c3c2cd6ec877e4263d2d6b399.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5c86419c3c2cd6ec877e4263d2d6b399.setIcon(icon_ed36dace9c8b6d8c6db9fd3ee165c948);
#
#
#             var marker_2ab345573e8dfd8c804df8f8c4ab94d2 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_3693e2429ab95d0badb25c9ebc3ae3c7);
#
#
#             var icon_76d3e49e74c048c502a3106119e4e764 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b9221b69a5659eb16cd991bb07905bd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8781e64340d162bf1baa391769645673 = $(`&lt;div id=&quot;html_8781e64340d162bf1baa3917696456

# %%
path_A_to_J_extreme = nav.create_path_map(path_A_to_J_extreme)
path_A_to_J_extreme
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c467418ca1f9fb4bf5f24b4a15aa7444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c467418ca1f9fb4bf5f24b4a15aa7444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c467418ca1f9fb4bf5f24b4a15aa7444 = L.map(
#                 &quot;map_c467418ca1f9fb4bf5f24b4a15aa7444&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9916b0ad562ed80bd1b5515c4deadc4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9916b0ad562ed80bd1b5515c4deadc4b.addTo(map_c467418ca1f9fb4bf5f24b4a15aa7444);
#
#
#             var marker_725854b88d730d198b3e32e7fa1341d8 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_c467418ca1f9fb4bf5f24b4a15aa7444);
#
#
#             var icon_a266c49a22802ea64ae103ffecc7da98 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_04267ca5ee9f196d5a5d1bd3003c064a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bd7c6f44c800eb7880c787b435e90d0 = $(`&lt;div id=&quot;html_2bd7c6f44c800eb7880c787b435e90d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_04267ca5ee9f196d5a5d1bd3003c064a.setContent(html_2bd7c6f44c800eb7880c787b435e90d0);
#
#
#
#         marker_725854b88d730d198b3e32e7fa1341d8.bindPopup(popup_04267ca5ee9f196d5a5d1bd3003c064a)
#         ;
#
#
#
#
#             marker_725854b88d730d198b3e32e7fa1341d8.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_725854b88d730d198b3e32e7fa1341d8.setIcon(icon_a266c49a22802ea64ae103ffecc7da98);
#
#
#             var marker_5ef2cdc1431030ac4aa0078a30e93770 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_c467418ca1f9fb4bf5f24b4a15aa7444);
#
#
#             var icon_c92b66d6bc68e5fad68d461c1a0a5d6e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f1f0c0fedc382cfd8c0f304d392cc203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cb8773cb47f24921316999078487a2b = $(`&lt;div id=&quot;html_7cb8773cb47f24921316999078487a2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_f1f0c0fedc382cfd8c0f304d392cc203.setContent(html_7cb8773cb47f24921316999078487a2b);
#
#
#
#         marker_5ef2cdc1431030ac4aa0078a30e93770.bindPopup(popup_f1f0c0fedc382cfd8c0f304d392cc203)
#         ;
#
#
#
#
#             marker_5ef2cdc1431030ac4aa0078a30e93770.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5ef2cdc1431030ac4aa0078a30e93770.setIcon(icon_c92b66d6bc68e5fad68d461c1a0a5d6e);
#
#
#             var marker_d3886d7450c43579999cd97cb858038e = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_c467418ca1f9fb4bf5f24b4a15aa7444);
#
#
#             var icon_3c10e72103888a54912a945941508dd4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c4546b03229d5ea5480167bddf138c80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c90493be28139751fa9cf83b316ab8ce = $(`&lt;div id=&quot;html_c90493be28139751fa9cf83b316ab8
