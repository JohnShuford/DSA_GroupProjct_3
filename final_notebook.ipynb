# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: folium in ./.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.13/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->folium) (2025.11.12)

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.graph.t_edgeWeight()
path_A_to_J_traffic = nav.find_route('A', 'J', traffic=True)
print("Path found with traffic:", path_A_to_J_traffic)
# Out:
# Path found with traffic: [0, 2, 3, 7, 8, 9]

# %%
nav.print_route_details('A', 'J')
nav.print_route_details('A', 'J', traffic = True)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================
#
#
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → C → D → H → I → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  C: Szczesliwicki Park (21.2 mins)
#  D: SGH Warsaw School of Economics (15.5 mins)
#  H: Palace of Culture and Science (8.5 mins)
#  I: National Museum in Warsaw (5.7 mins)
#  J: PGE Narodowy Stadium (11.2 mins)
#
# Total Travel Time: 62.0 minutes
# ============================================================

# %%
# Base Case with Uncertainty
nav.graph.apply_uncertainty()
path = nav.find_route("A", "J", traffic=False)
nav.print_route_details("A", "J", traffic=False)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================

# %%
# Traffic Case with Uncertainty & Traffic Multiplier
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
path = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (13.6 mins)
#  D: SGH Warsaw School of Economics (25.3 mins)
#  F: Legia Warsaw Stadium (21.4 mins)
#  J: PGE Narodowy Stadium (4.2 mins)
#
# Total Travel Time: 64.5 minutes
# ============================================================

# %%
# Traffic Case with Extreme Events
nav.graph.t_edgeWeight()
nav.graph.apply_uncertainty()
nav.graph.apply_extreme_events(num_edges=3)
# Out:
#  Extreme Event Report
# No disruption on edge 1-2 (normal conditions)
# No disruption on edge 1-3 (normal conditions)
# Disruption on edge 0-1: 8.8 → 88.4 mins
# {(0, 1): 88.38,
#  (1, 0): 88.38,
#  (0, 2): 10.860000000000001,
#  (2, 0): 10.860000000000001,
#  (1, 2): 13.258,
#  (2, 1): 13.258,
#  (1, 3): 10.78,
#  (3, 1): 10.78,
#  (2, 3): 11.424,
#  (3, 2): 11.424,
#  (2, 4): 9.58,
#  (4, 2): 9.58,
#  (3, 5): 8.68,
#  (5, 3): 8.68,
#  (3, 7): 7.864,
#  (7, 3): 7.864,
#  (4, 7): 11.796,
#  (7, 4): 11.796,
#  (4, 8): 13.116,
#  (8, 4): 13.116,
#  (5, 6): 5.766,
#  (6, 5): 5.766,
#  (5, 9): 3.888,
#  (9, 5): 3.888,
#  (6, 8): 5.67,
#  (8, 6): 5.67,
#  (6, 9): 5.862,
#  (9, 6): 5.862,
#  (7, 8): 2.889,
#  (8, 7): 2.889,
#  (8, 9): 5.415,
#  (9, 8): 5.415}

# %%
path = nav.find_route("A", "J", traffic=True)
nav.print_route_details("A", "J", traffic=True)
# Out:
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → C → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  C: Szczesliwicki Park (19.9 mins)
#  D: SGH Warsaw School of Economics (13.8 mins)
#  F: Legia Warsaw Stadium (13.5 mins)
#  J: PGE Narodowy Stadium (4.5 mins)
#
# Total Travel Time: 51.7 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5bc747d48e58dba827839fe201435d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5bc747d48e58dba827839fe201435d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5bc747d48e58dba827839fe201435d1 = L.map(
#                 &quot;map_a5bc747d48e58dba827839fe201435d1&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_738e16a639d91fa4ae16774433c81fb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_738e16a639d91fa4ae16774433c81fb0.addTo(map_a5bc747d48e58dba827839fe201435d1);
#
#
#             var marker_f17770615554ca804a14c38fbfc0398d = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_a5bc747d48e58dba827839fe201435d1);
#
#
#             var icon_1b769bc20e28b57b46adafffc68fccf1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ab68505434ab448f6f2d5c82c96c5536 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45eab25a5add2341e96c95cbb95143ec = $(`&lt;div id=&quot;html_45eab25a5add2341e96c95cbb95143ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_ab68505434ab448f6f2d5c82c96c5536.setContent(html_45eab25a5add2341e96c95cbb95143ec);
#
#
#
#         marker_f17770615554ca804a14c38fbfc0398d.bindPopup(popup_ab68505434ab448f6f2d5c82c96c5536)
#         ;
#
#
#
#
#             marker_f17770615554ca804a14c38fbfc0398d.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f17770615554ca804a14c38fbfc0398d.setIcon(icon_1b769bc20e28b57b46adafffc68fccf1);
#
#
#             var marker_538e5d45604c35d4fa8642b37f173046 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_a5bc747d48e58dba827839fe201435d1);
#
#
#             var icon_fa677f5d5bbba140d258c189d4dfbe69 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3affbc2601d758ef7cc1b707060fc3dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_909c58d2acde6c6143cfea19c1c3fc29 = $(`&lt;div id=&quot;html_909c58d2acde6c6143cfea19c1c3fc29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_3affbc2601d758ef7cc1b707060fc3dd.setContent(html_909c58d2acde6c6143cfea19c1c3fc29);
#
#
#
#         marker_538e5d45604c35d4fa8642b37f173046.bindPopup(popup_3affbc2601d758ef7cc1b707060fc3dd)
#         ;
#
#
#
#
#             marker_538e5d45604c35d4fa8642b37f173046.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_538e5d45604c35d4fa8642b37f173046.setIcon(icon_fa677f5d5bbba140d258c189d4dfbe69);
#
#
#             var marker_8a97dd3d2357e8e30a7a36aa1e82b899 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_a5bc747d48e58dba827839fe201435d1);
#
#
#             var icon_bef895d27f567addea997e490fd3d181 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ac3a99e013d1450f8471e19c03149cc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e2fa2decbfda2d2c875467e31858e45 = $(`&lt;div id=&quot;html_8e2fa2decbfda2d2c875467e31858e4

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c757d46c8b569dec6a183099661f5af7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c757d46c8b569dec6a183099661f5af7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c757d46c8b569dec6a183099661f5af7 = L.map(
#                 &quot;map_c757d46c8b569dec6a183099661f5af7&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0281845fc1096ec6a69c1617337f805f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0281845fc1096ec6a69c1617337f805f.addTo(map_c757d46c8b569dec6a183099661f5af7);
#
#
#             var marker_4ca0acdbd42ee16323bbdd8d96859b93 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_c757d46c8b569dec6a183099661f5af7);
#
#
#             var icon_5a2b6a05cb0e0906e148b9c9a16754b9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b2d6862ead6bec6c2504cd272048e67c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa2d4c8156fd0bf5949b94e37af458e1 = $(`&lt;div id=&quot;html_fa2d4c8156fd0bf5949b94e37af458e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_b2d6862ead6bec6c2504cd272048e67c.setContent(html_fa2d4c8156fd0bf5949b94e37af458e1);
#
#
#
#         marker_4ca0acdbd42ee16323bbdd8d96859b93.bindPopup(popup_b2d6862ead6bec6c2504cd272048e67c)
#         ;
#
#
#
#
#             marker_4ca0acdbd42ee16323bbdd8d96859b93.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4ca0acdbd42ee16323bbdd8d96859b93.setIcon(icon_5a2b6a05cb0e0906e148b9c9a16754b9);
#
#
#             var marker_b99f70df38e396586447dbec25244eb2 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_c757d46c8b569dec6a183099661f5af7);
#
#
#             var icon_5d8fa2eb36773f1fc78433d5c6f8c0d8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ae11980362c3fe08e7863f753731858f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac61d342361611a3f10db405a4481b7f = $(`&lt;div id=&quot;html_ac61d342361611a3f10db405a4481b7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_ae11980362c3fe08e7863f753731858f.setContent(html_ac61d342361611a3f10db405a4481b7f);
#
#
#
#         marker_b99f70df38e396586447dbec25244eb2.bindPopup(popup_ae11980362c3fe08e7863f753731858f)
#         ;
#
#
#
#
#             marker_b99f70df38e396586447dbec25244eb2.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b99f70df38e396586447dbec25244eb2.setIcon(icon_5d8fa2eb36773f1fc78433d5c6f8c0d8);
#
#
#             var marker_a89a643e2f53d177f26dab57cfe6d784 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_c757d46c8b569dec6a183099661f5af7);
#
#
#             var icon_351dd6f2053e4c4a397052b5933aa901 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0d086a58bf9b1989f5ec532ed64c8cb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3cee1953c3ccf6767f56110d566779b = $(`&lt;div id=&quot;html_d3cee1953c3ccf6767f56110d56677

# %%
map_A_to_J_traffic = nav.create_path_map(path_A_to_J_traffic)
map_A_to_J_traffic
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f4b4ba5497078ce574f6f892becead2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f4b4ba5497078ce574f6f892becead2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f4b4ba5497078ce574f6f892becead2 = L.map(
#                 &quot;map_5f4b4ba5497078ce574f6f892becead2&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_711030ba03a561ba1a7041c44ea3ac9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_711030ba03a561ba1a7041c44ea3ac9e.addTo(map_5f4b4ba5497078ce574f6f892becead2);
#
#
#             var marker_87c49281a48f8f2ac8a2de21e2d036c5 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_5f4b4ba5497078ce574f6f892becead2);
#
#
#             var icon_e6419232cd77123a86356d309aa982f6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_64ca37ff655e971766312434013edee6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df122251fc0af7eaeac25c3ea062afab = $(`&lt;div id=&quot;html_df122251fc0af7eaeac25c3ea062afab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_64ca37ff655e971766312434013edee6.setContent(html_df122251fc0af7eaeac25c3ea062afab);
#
#
#
#         marker_87c49281a48f8f2ac8a2de21e2d036c5.bindPopup(popup_64ca37ff655e971766312434013edee6)
#         ;
#
#
#
#
#             marker_87c49281a48f8f2ac8a2de21e2d036c5.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_87c49281a48f8f2ac8a2de21e2d036c5.setIcon(icon_e6419232cd77123a86356d309aa982f6);
#
#
#             var marker_71b5f58bbe10b0802c97d61c7d218385 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_5f4b4ba5497078ce574f6f892becead2);
#
#
#             var icon_2db080751bb60c7d0d81707cce969114 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fcbe4e50598b82a873fd4b28e6cb2eb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6d3622b9444a19f1affd1f9f8507dad = $(`&lt;div id=&quot;html_b6d3622b9444a19f1affd1f9f8507dad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_fcbe4e50598b82a873fd4b28e6cb2eb3.setContent(html_b6d3622b9444a19f1affd1f9f8507dad);
#
#
#
#         marker_71b5f58bbe10b0802c97d61c7d218385.bindPopup(popup_fcbe4e50598b82a873fd4b28e6cb2eb3)
#         ;
#
#
#
#
#             marker_71b5f58bbe10b0802c97d61c7d218385.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_71b5f58bbe10b0802c97d61c7d218385.setIcon(icon_2db080751bb60c7d0d81707cce969114);
#
#
#             var marker_fb7b3d6716bab715efc3d1d7a7613623 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_5f4b4ba5497078ce574f6f892becead2);
#
#
#             var icon_c80857dda9b96d5393f213d23a39f4a2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2f8427c8ed2b212362e5b9a6bf44b3f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c16249aaea3f609feda8e26e12049522 = $(`&lt;div id=&quot;html_c16249aaea3f609feda8e26e120495
