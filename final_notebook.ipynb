# %%
#!pip install pandas folium

# %%
import sys
sys.path.append('src')

from warsaw_navigator import WarsawNavigator

# %%
nav = WarsawNavigator('data/warsaw_nodes.csv', 'data/warsaw_connections.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 10
# Total edges: 16

# %%
path_A_to_J = nav.find_route('A', 'J')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 1, 3, 5, 9]

# %%
nav.graph.t_edgeWeight()
path_A_to_J_traffic = nav.find_route('A', 'J', traffic=True)
print("Path found with traffic:", path_A_to_J)
# Out:
# Path found with traffic: [0, 1, 3, 5, 9]

# %%
nav.print_route_details('A', 'J')
nav.print_route_details('A', 'J', traffic = True)
# Out:
# ============================================================
# Route from A to J; no traffic
# ============================================================
#
# Path (Letters):
# A → B → D → F → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (9 mins)
#  D: SGH Warsaw School of Economics (11 mins)
#  F: Legia Warsaw Stadium (8 mins)
#  J: PGE Narodowy Stadium (4 mins)
#
# Total Travel Time: 32 minutes
# ============================================================
#
#
# ============================================================
# Route from A to J with traffic
# ============================================================
#
# Path (Letters):
# A → B → D → H → I → J
#
# Path (Locations):
#  A: Warsaw Chopin Airport (start)
#  B: Sluzewiec Horse Racetrack (20.3 mins)
#  D: SGH Warsaw School of Economics (20.2 mins)
#  H: Palace of Culture and Science (11.4 mins)
#  I: National Museum in Warsaw (6.1 mins)
#  J: PGE Narodowy Stadium (8.6 mins)
#
# Total Travel Time: 66.7 minutes
# ============================================================

# %%
full_map = nav.create_map()
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f259fdcda3ef5253e37ba924de508f03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f259fdcda3ef5253e37ba924de508f03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f259fdcda3ef5253e37ba924de508f03 = L.map(
#                 &quot;map_f259fdcda3ef5253e37ba924de508f03&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_066759b447984861802e492a9346aa75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_066759b447984861802e492a9346aa75.addTo(map_f259fdcda3ef5253e37ba924de508f03);
#
#
#             var marker_2fd50b43d1197fe33dcd49b32dc83ec5 = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_f259fdcda3ef5253e37ba924de508f03);
#
#
#             var icon_b73e567bb2422395da4b135dc35c5d91 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_43de8c8811716aeea6a47bf29272ccfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a92080d80fdb869892cec6c3e9a2936e = $(`&lt;div id=&quot;html_a92080d80fdb869892cec6c3e9a2936e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_43de8c8811716aeea6a47bf29272ccfa.setContent(html_a92080d80fdb869892cec6c3e9a2936e);
#
#
#
#         marker_2fd50b43d1197fe33dcd49b32dc83ec5.bindPopup(popup_43de8c8811716aeea6a47bf29272ccfa)
#         ;
#
#
#
#
#             marker_2fd50b43d1197fe33dcd49b32dc83ec5.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2fd50b43d1197fe33dcd49b32dc83ec5.setIcon(icon_b73e567bb2422395da4b135dc35c5d91);
#
#
#             var marker_55e51b3cb00da64edab9b3379c644c20 = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_f259fdcda3ef5253e37ba924de508f03);
#
#
#             var icon_db0839edab02fda79eb8ff35d2ff7a26 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_453dfc4263bfdf0bf2af85c4ff3d6f3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_670de4f1a69e6b40f18af4a938d7f583 = $(`&lt;div id=&quot;html_670de4f1a69e6b40f18af4a938d7f583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_453dfc4263bfdf0bf2af85c4ff3d6f3a.setContent(html_670de4f1a69e6b40f18af4a938d7f583);
#
#
#
#         marker_55e51b3cb00da64edab9b3379c644c20.bindPopup(popup_453dfc4263bfdf0bf2af85c4ff3d6f3a)
#         ;
#
#
#
#
#             marker_55e51b3cb00da64edab9b3379c644c20.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_55e51b3cb00da64edab9b3379c644c20.setIcon(icon_db0839edab02fda79eb8ff35d2ff7a26);
#
#
#             var marker_6354ff7c0fe63b88f863c57a182e55e0 = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_f259fdcda3ef5253e37ba924de508f03);
#
#
#             var icon_786c4698291f0f6172974621499191a3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_59f1692b28c087011251d26d46d731ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5148ac1f93997fe092fa25dc9d2f0a17 = $(`&lt;div id=&quot;html_5148ac1f93997fe092fa25dc9d2f0a1

# %%
map_A_to_J = nav.create_path_map(path_A_to_J)
map_A_to_J
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2dfa12f766a306fef1e3399834dc5d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2dfa12f766a306fef1e3399834dc5d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2dfa12f766a306fef1e3399834dc5d2 = L.map(
#                 &quot;map_f2dfa12f766a306fef1e3399834dc5d2&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_899c92a5dcda859a738a616c5a934453 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_899c92a5dcda859a738a616c5a934453.addTo(map_f2dfa12f766a306fef1e3399834dc5d2);
#
#
#             var marker_7535aa9efa74c9d0b6ad24051401c39b = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_f2dfa12f766a306fef1e3399834dc5d2);
#
#
#             var icon_aa2d9064401a37baa48333c909a5e035 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0a94910b1dc28575dbd2e588d32508f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_050f9887785315efb6ec707c3dafa345 = $(`&lt;div id=&quot;html_050f9887785315efb6ec707c3dafa345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_0a94910b1dc28575dbd2e588d32508f2.setContent(html_050f9887785315efb6ec707c3dafa345);
#
#
#
#         marker_7535aa9efa74c9d0b6ad24051401c39b.bindPopup(popup_0a94910b1dc28575dbd2e588d32508f2)
#         ;
#
#
#
#
#             marker_7535aa9efa74c9d0b6ad24051401c39b.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7535aa9efa74c9d0b6ad24051401c39b.setIcon(icon_aa2d9064401a37baa48333c909a5e035);
#
#
#             var marker_3fb636be61af0e2b83c736e44bfaad4c = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_f2dfa12f766a306fef1e3399834dc5d2);
#
#
#             var icon_a00715ad4c03b3ef028a6810d278e0b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_412303001b785a8fae33016b4d12a7b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6941ae5d9317bb24c7c66d8ec43ffb96 = $(`&lt;div id=&quot;html_6941ae5d9317bb24c7c66d8ec43ffb96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_412303001b785a8fae33016b4d12a7b7.setContent(html_6941ae5d9317bb24c7c66d8ec43ffb96);
#
#
#
#         marker_3fb636be61af0e2b83c736e44bfaad4c.bindPopup(popup_412303001b785a8fae33016b4d12a7b7)
#         ;
#
#
#
#
#             marker_3fb636be61af0e2b83c736e44bfaad4c.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3fb636be61af0e2b83c736e44bfaad4c.setIcon(icon_a00715ad4c03b3ef028a6810d278e0b2);
#
#
#             var marker_e879b205e5d7e48c7751bc805063b8bf = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_f2dfa12f766a306fef1e3399834dc5d2);
#
#
#             var icon_75dbb48845aad79162b3d77f2b7be76c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_33fe2a0a8053d0c0689cc8e99361306d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26838b2e719df8b57b63a75629af908d = $(`&lt;div id=&quot;html_26838b2e719df8b57b63a75629af90

# %%
map_A_to_J_traffic = nav.create_path_map(path_A_to_J_traffic)
map_A_to_J_traffic
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd69f7d1151257e5b9398db219110e8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd69f7d1151257e5b9398db219110e8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd69f7d1151257e5b9398db219110e8b = L.map(
#                 &quot;map_dd69f7d1151257e5b9398db219110e8b&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6325e5b865fa9e93777a54de0b9744e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6325e5b865fa9e93777a54de0b9744e0.addTo(map_dd69f7d1151257e5b9398db219110e8b);
#
#
#             var marker_971fe4eaeee6cdf0df5fba74693a151f = L.marker(
#                 [52.1631, 20.9708],
#                 {
# }
#             ).addTo(map_dd69f7d1151257e5b9398db219110e8b);
#
#
#             var icon_6e78de571a8c36fce3b64976a6a1017f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bc415fa17f1327bffe637a9bf812c3d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b944e09ac814e54fbbf5b110495c8ae = $(`&lt;div id=&quot;html_9b944e09ac814e54fbbf5b110495c8ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: Warsaw Chopin Airport&lt;/div&gt;`)[0];
#                 popup_bc415fa17f1327bffe637a9bf812c3d5.setContent(html_9b944e09ac814e54fbbf5b110495c8ae);
#
#
#
#         marker_971fe4eaeee6cdf0df5fba74693a151f.bindPopup(popup_bc415fa17f1327bffe637a9bf812c3d5)
#         ;
#
#
#
#
#             marker_971fe4eaeee6cdf0df5fba74693a151f.bindTooltip(
#                 `&lt;div&gt;
#                      A: Warsaw Chopin Airport
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_971fe4eaeee6cdf0df5fba74693a151f.setIcon(icon_6e78de571a8c36fce3b64976a6a1017f);
#
#
#             var marker_1d413fff02af61fab5b9e24eeb5f285d = L.marker(
#                 [52.1657, 21.0175],
#                 {
# }
#             ).addTo(map_dd69f7d1151257e5b9398db219110e8b);
#
#
#             var icon_496cbc48db846597c350233770b7e9ef = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b435b15b9db491750e027bc5eef22010 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e2cf6933292e7bc0f0aa3ce5addaea1 = $(`&lt;div id=&quot;html_2e2cf6933292e7bc0f0aa3ce5addaea1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: Sluzewiec Horse Racetrack&lt;/div&gt;`)[0];
#                 popup_b435b15b9db491750e027bc5eef22010.setContent(html_2e2cf6933292e7bc0f0aa3ce5addaea1);
#
#
#
#         marker_1d413fff02af61fab5b9e24eeb5f285d.bindPopup(popup_b435b15b9db491750e027bc5eef22010)
#         ;
#
#
#
#
#             marker_1d413fff02af61fab5b9e24eeb5f285d.bindTooltip(
#                 `&lt;div&gt;
#                      B: Sluzewiec Horse Racetrack
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1d413fff02af61fab5b9e24eeb5f285d.setIcon(icon_496cbc48db846597c350233770b7e9ef);
#
#
#             var marker_7de0aee189224fee9b7e6438bdaa62ee = L.marker(
#                 [52.2054, 20.9594],
#                 {
# }
#             ).addTo(map_dd69f7d1151257e5b9398db219110e8b);
#
#
#             var icon_4b5d44ade4391e91ea4eb2f75558c055 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_221f9182b6890df66b4c68af7ae8527a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c3622694b2a4aafdd557709f53ec610 = $(`&lt;div id=&quot;html_9c3622694b2a4aafdd557709f53ec6
